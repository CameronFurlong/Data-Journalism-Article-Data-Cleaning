# %%
import pandas as pd
import numpy as np
Ethnicity_csv = "/Ethnicity Data 2013-2022.csv"
Ethnicity_df = pd.read_csv(Ethnicity_csv,delimiter=",")

# %%
Ethnicity_df.head(10)
# Out:
#                 Country of Birth Type of Attendance Unnamed: 2   Gender  \
# 0                            NaN          Full-time  Part-time    Males
# 1                      Australia                NaN        NaN      NaN
# 2                      Australia            521,040    247,846  317,018
# 3         Oceania and Antarctica                NaN        NaN      NaN
# 4  Australian Antartic Territory                 49         66       37
# 5                   Cook Islands                 44         28       28
# 6                           Fiji              1,636      1,346    1,211
# 7               French Polynesia                 13         11        9
# 8                       Kiribati                  7         14       11
# 9                          Nauru                 15          5        7
#
#   Unnamed: 4                              Unnamed: 5    Unnamed: 6    TOTAL
# 0    Females  Indeterminate/\nIntersex/\nUnspecified  Not provided      NaN
# ...

# %%
Ethnicity_df = Ethnicity_df.drop('Gender', axis=1)
Ethnicity_df = Ethnicity_df.drop('Unnamed: 4', axis=1)
Ethnicity_df = Ethnicity_df.drop('Unnamed: 5', axis=1)
Ethnicity_df = Ethnicity_df.drop('Unnamed: 6', axis=1)

# %%
Ethnicity_df.head()
# Out:
#                 Country of Birth Type of Attendance Unnamed: 2    TOTAL
# 0                            NaN          Full-time  Part-time      NaN
# 1                      Australia                NaN        NaN      NaN
# 2                      Australia            521,040    247,846  768,886
# 3         Oceania and Antarctica                NaN        NaN      NaN
# 4  Australian Antartic Territory                 49         66      115

# %%
Ethnicity_df=Ethnicity_df.dropna()
Ethnicity_df
# Out:
#                            Country of Birth Type of Attendance Unnamed: 2  \
# 2                                 Australia            521,040    247,846
# 4             Australian Antartic Territory                 49         66
# 5                              Cook Islands                 44         28
# 6                                      Fiji              1,636      1,346
# 7                          French Polynesia                 13         11
# ...                                     ...                ...        ...
# 1915                               Zimbabwe              1,969      1,911
# 1916  Countries with fewer than 20 students                 64         80
# 1917                           Not provided              6,681      3,768
# 1918                             Total 2021            678,451    424,306
# 1919                       % change on 2021            730,142    432,118
#
#           TOTAL
# 2       768,886
# 4           115
# 5            72
# ...

# %%
Ethnicity_df.rename(columns={"Type of Attendance": "Full-Time", "Unnamed: 2": "Part-Time"})
# Out:
#                            Country of Birth Full-Time Part-Time      TOTAL
# 2                                 Australia   521,040   247,846    768,886
# 4             Australian Antartic Territory        49        66        115
# 5                              Cook Islands        44        28         72
# 6                                      Fiji     1,636     1,346      2,982
# 7                          French Polynesia        13        11         24
# ...                                     ...       ...       ...        ...
# 1915                               Zimbabwe     1,969     1,911      3,880
# 1916  Countries with fewer than 20 students        64        80        144
# 1917                           Not provided     6,681     3,768     10,449
# 1918                             Total 2021   678,451   424,306  1,102,757
# 1919                       % change on 2021   730,142   432,118  1,162,260
#
# [1815 rows x 4 columns]

# %%
country_df = sorted(Ethnicity_df['Country of Birth'].unique())

country_df
# Out:
# ['% change on 2012',
#  '% change on 2013',
#  '% change on 2014',
#  '% change on 2015',
#  '% change on 2016',
#  '% change on 2017',
#  '% change on 2018',
#  '% change on 2019',
#  '% change on 2020',
#  '% change on 2021',
#  'Adélie Land (France)',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Australian Antartic Territory',
#  'Australian External Territories, nec',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Antartic Territory',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burma (Myanmar)',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central and West Africa, nfd',
#  'Channel Islands',
#  'Chile',
#  'China (excludes SARs and Taiwan Province)',
#  'China (excludes SARs and Taiwan)',
#  'Chinese Asia (includes Mongolia), nfd',
#  'Colombia',
# ...

# %%
totals_df = Ethnicity_df[(Ethnicity_df['Country of Birth'] == 'Brazil')]

totals_df
# Out:
#      Country of Birth Type of Attendance Unnamed: 2  TOTAL
# 137            Brazil                402        416    818
# 335            Brazil                448        414    862
# 536            Brazil                457        465    922
# 735            Brazil                463        524    987
# 933            Brazil                512        553  1,065
# 1128           Brazil                523        574  1,097
# 1324           Brazil                537        595  1,132
# 1509           Brazil                654        746  1,400
# 1691           Brazil                674        839  1,513
# 1869           Brazil                665        811  1,476

# %%
#Ethnicity_df.to_csv('CleanedEthnicityData.csv')

# %%
Ethnicity_df.str.extract(r'Total')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-cdec225fde5d> in <cell line: 1>()
# ----> 1 Ethnicity_df.str.extract(r'Total')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'str'
